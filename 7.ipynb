# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\HP\Desktop\waste-main\waste-main\example.csv')
print(df)
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
df_1 = df[(df['gender'] == 'Male')]
df_1
# Out:
#        id first_name   last_name                           email gender  \
# 0       1     Joseph   Zaniolini  jzaniolini0@simplemachines.org   Male
# 3       4     Orazio    Frayling        ofrayling3@economist.com   Male
# 8       9    Chrissy    Hedworth         chedworth8@china.com.cn   Male
# 9      10      Hyatt   Gasquoine           hgasquoine9@google.ru   Male
# 11     12     Andrew        Bath                  abathb@umn.edu   Male
# ..    ...        ...         ...                             ...    ...
# 994   995      Glynn    Wakerley          gwakerleyrm@disqus.com   Male
# 995   996   Parrnell        Jeff             pjeffrn@4shared.com   Male
# 996   997        Pat    Warstall         pwarstallro@dropbox.com   Male
# 998   999     Gaelan  Petrashkov     gpetrashkovrq@hostgator.com   Male
# 999  1000   Stirling    Francesc     sfrancescrr@cyberchimps.com   Male
#
#          ip_address                 city
# 0    163.168.68.132       Pedro Leopoldo
# ...

# %%
df_2 = df_1[['first_name', 'last_name']]
df_2
# Out:
#     first_name   last_name
# 0       Joseph   Zaniolini
# 3       Orazio    Frayling
# 8      Chrissy    Hedworth
# 9        Hyatt   Gasquoine
# 11      Andrew        Bath
# ..         ...         ...
# 994      Glynn    Wakerley
# 995   Parrnell        Jeff
# 996        Pat    Warstall
# 998     Gaelan  Petrashkov
# 999   Stirling    Francesc
#
# [486 rows x 2 columns]

# %%
df_3 = df[(df.city== "Claver") | (df['city'] == 'Buri')]
df_3
# Out:
#    id first_name      last_name                      email  gender  \
# 1   2     Freida  Drillingcourt  fdrillingcourt1@umich.edu  Female
# 2   3      Nanni         Herity   nherity2@statcounter.com  Female
#
#        ip_address    city
# 1   97.212.102.79    Buri
# 2  145.151.178.98  Claver

# %%
df_4 = df[df.first_name.str.startswith('S')]
df_4
# Out:
#        id first_name     last_name                          email  gender  \
# 24     25     Sarina    Choulerton          schoulertono@wisc.edu  Female
# 31     32  Sutherlan        Mundee            smundeev@nsw.gov.au    Male
# 50     51   Salvidor       Cawthry            scawthry1e@youtu.be    Male
# 66     67     Salomi       Pinnock           spinnock1u@hc360.com  Female
# 69     70    Stormie        Dougal               sdougal1x@cbc.ca  Female
# 83     84    Sigmund      Sessions    ssessions2b@bizjournals.com    Male
# 91     92     Skelly         Cragg             scragg2j@naver.com    Male
# 107   108       Susi        Pawsey           spawsey2z@zimbio.com  Female
# 136   137      Silva       Pittham             spittham3s@ibm.com  Female
# 197   198     Sanson       Ramelot         sramelot5h@smugmug.com    Male
# 211   212    Sibilla      Stachini         sstachini5v@dyndns.org  Female
# 234   235       Shep         Voyce          svoyce6i@linkedin.com    Male
# ...

# %%
df_5 = df_4[['email']]
df_5
# Out:
#                              email
# 24           schoulertono@wisc.edu
# 31             smundeev@nsw.gov.au
# 50             scawthry1e@youtu.be
# 66            spinnock1u@hc360.com
# 69                sdougal1x@cbc.ca
# 83     ssessions2b@bizjournals.com
# 91              scragg2j@naver.com
# 107           spawsey2z@zimbio.com
# 136             spittham3s@ibm.com
# 197         sramelot5h@smugmug.com
# 211         sstachini5v@dyndns.org
# 234          svoyce6i@linkedin.com
# 256      sstollsteimer74@mysql.com
# 264     sbutterfint7c@redcross.org
# 266        santoniades7e@salon.com
# 285             salesi7x@chron.com
# 304          smcgeady8g@disqus.com
# 330              ssherland96@de.vu
# 342                 shurt9i@goo.gl
# 343            sblumson9j@yelp.com
# 352              smcmychem9s@ow.ly
# 358           smcgrill9y@ocn.ne.jp
# 389         smiskimmonat@vimeo.com
# 411         sarseybf@newyorker.com
# 416          sderksbk@netvibes.com
# 424          shegdonnebs@wufoo.com
# ...

# %%
df_6 = df[df.gender == "Female"]
df_7 = df_6[['last_name', 'city']]
df_7
# Out:
#          last_name                   city
# 1    Drillingcourt                   Buri
# 2           Herity                 Claver
# 4         Murrison  Sainte-Luce-sur-Loire
# 5            Gamet               Pak Phli
# 6           Howatt               Palmares
# ..             ...                    ...
# 983   Drew-Clifton                Guariba
# 989         Nilles          Sherwood Park
# 991      Sheavills              Thanatpin
# 992      Marvelley             Kleszczewo
# 997     Vannuccini             Xiaopingba
#
# [514 rows x 2 columns]
